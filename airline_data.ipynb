# %% [markdown]
# # *FASE 1: EXPLORACIÓN Y LIMPIEZA* #

# %%
# Tratamiento de datos: importaciones
import pandas as pd
import numpy as np

# Para una mejor viualización de tidas las columnas
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## 1.1. EXPLORACIÓN INICIAL ##

# %% [markdown]
# ### REVISIÓN Y ANÁLISIS DE LOS DATOS DEL CSV ###

# %%
# Lectura de los datos del primer CSV y creación del Data Frame correspondiente
df_flight = pd.read_csv('../Customer Flight Activity.csv')
#Revisamos las dos primeras filas para ver la info de las columnas sin necesidad de cargar todo el DF
df_flight.head(2)
# Out:
#    Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 0          100018  2017      1               3                        0
# 1          100102  2017      1              10                        4
#
#    Total Flights  Distance  Points Accumulated  Points Redeemed  \
# 0              3      1521               152.0                0
# 1             14      2030               203.0                0
#
#    Dollar Cost Points Redeemed
# 0                            0
# 1                            0

# %%
# Reviso la forma de mi DF (cuántas filas y columnas tiene)
print(df_flight.shape)
print(f"El número de filas que tenemos es {df_flight.shape[0]}, y el número de columnas es {df_flight.shape[1]}")
# Out:
# (405624, 10)
# El número de filas que tenemos es 405624, y el número de columnas es 10

# %%
# Revisamos el número total de valores del DF
df_flight.size
# Out:
# 4056240

# %%
# Ver dos filas al azar
df_flight.sample(2)
# Out:
#        Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 83566          950391  2017      5               3                        3
# 31145          856496  2017      2               0                        0
#
#        Total Flights  Distance  Points Accumulated  Points Redeemed  \
# 83566              6      1458               145.0                0
# 31145              0         0                 0.0                0
#
#        Dollar Cost Points Redeemed
# 83566                            0
# 31145                            0

# %%
#Revisamos las dos últimas filas
df_flight.tail(2)
# Out:
#         Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 405622          999982  2018     12               0                        0
# 405623          999986  2018     12               0                        0
#
#         Total Flights  Distance  Points Accumulated  Points Redeemed  \
# 405622              0         0                 0.0                0
# 405623              0         0                 0.0                0
#
#         Dollar Cost Points Redeemed
# 405622                            0
# 405623                            0

# %%
#Reviso el nombre de todas las columnas del DF
df_flight.columns
# Out:
# Index(['Loyalty Number', 'Year', 'Month', 'Flights Booked',
#        'Flights with Companions', 'Total Flights', 'Distance',
#        'Points Accumulated', 'Points Redeemed', 'Dollar Cost Points Redeemed'],
#       dtype='object')

# %%
# Reviso los principales datos estadísticos del DF
df_flight.describe()
# Out:
#        Loyalty Number           Year          Month  Flights Booked  \
# count   405624.000000  405624.000000  405624.000000   405624.000000
# mean    550037.873084    2017.500000       6.500000        4.115052
# std     258935.286969       0.500001       3.452057        5.225518
# min     100018.000000    2017.000000       1.000000        0.000000
# 25%     326961.000000    2017.000000       3.750000        0.000000
# 50%     550834.000000    2017.500000       6.500000        1.000000
# 75%     772194.000000    2018.000000       9.250000        8.000000
# max     999986.000000    2018.000000      12.000000       21.000000
#
#        Flights with Companions  Total Flights       Distance  \
# count            405624.000000  405624.000000  405624.000000
# mean                  1.031805       5.146858    1208.880059
# std                   2.076869       6.521227    1433.155320
# min                   0.000000       0.000000       0.000000
# 25%                   0.000000       0.000000       0.000000
# 50%                   0.000000       1.000000     488.000000
# 75%                   1.000000      10.000000    2336.000000
# max                  11.000000      32.000000    6293.000000
#
#        Points Accumulated  Points Redeemed  Dollar Cost Points Redeemed
# count       405624.000000    405624.000000                405624.000000
# mean           123.692721        30.696872                     2.484503
# std            146.599831       125.486049                    10.150038
# min              0.000000         0.000000                     0.000000
# 25%              0.000000         0.000000                     0.000000
# 50%             50.000000         0.000000                     0.000000
# 75%            239.000000         0.000000                     0.000000
# max            676.500000       876.000000                    71.000000

# %%
# Transponemos los resultados para visualizar los datos en función de los datos estadísticos
df_flight.describe().T
# Out:
#                                 count           mean            std       min  \
# Loyalty Number               405624.0  550037.873084  258935.286969  100018.0
# Year                         405624.0    2017.500000       0.500001    2017.0
# Month                        405624.0       6.500000       3.452057       1.0
# Flights Booked               405624.0       4.115052       5.225518       0.0
# Flights with Companions      405624.0       1.031805       2.076869       0.0
# Total Flights                405624.0       5.146858       6.521227       0.0
# Distance                     405624.0    1208.880059    1433.155320       0.0
# Points Accumulated           405624.0     123.692721     146.599831       0.0
# Points Redeemed              405624.0      30.696872     125.486049       0.0
# Dollar Cost Points Redeemed  405624.0       2.484503      10.150038       0.0
#
#                                    25%       50%        75%       max
# Loyalty Number               326961.00  550834.0  772194.00  999986.0
# Year                           2017.00    2017.5    2018.00    2018.0
# Month                             3.75       6.5       9.25      12.0
# Flights Booked                    0.00       1.0       8.00      21.0
# Flights with Companions           0.00       0.0       1.00      11.0
# Total Flights                     0.00       1.0      10.00      32.0
# Distance                          0.00     488.0    2336.00    6293.0
# Points Accumulated                0.00      50.0     239.00     676.5
# Points Redeemed                   0.00       0.0       0.00     876.0
# Dollar Cost Points Redeemed       0.00       0.0       0.00      71.0

# %%
# Lectura de los datos del segundo CSV y creación del Data Frame correspondiente
df_loyalty = pd.read_csv('../Customer Loyalty History.csv')

df_loyalty.head(2)
# Out:
#    Loyalty Number Country Province      City Postal Code  Gender Education  \
# 0          480934  Canada  Ontario   Toronto     M2Z 4K1  Female  Bachelor
# 1          549612  Canada  Alberta  Edmonton     T3G 6Y6    Male   College
#
#     Salary Marital Status Loyalty Card      CLV Enrollment Type  \
# 0  83236.0        Married         Star  3839.14        Standard
# 1      NaN       Divorced         Star  3839.61        Standard
#
#    Enrollment Year  Enrollment Month  Cancellation Year  Cancellation Month
# 0             2016                 2                NaN                 NaN
# 1             2016                 3                NaN                 NaN

# %%
print(f'La forma de mi data frame es la siguiente: {df_loyalty.shape}')
#Obervamos que este DF tiene el muchísimas menos filas que el anterior DF pero tiene más columnas.
# Out:
# La forma de mi data frame es la siguiente: (16737, 16)

# %%
# Revisamos el número total de valores del DF
df_loyalty.size
# Out:
# 267792

# %%
df_loyalty.sample(10)
# Out:
#        Loyalty Number Country          Province          City Postal Code  \
# 1800           746235  Canada            Quebec      Montreal     H2T 9K8
# 9940           127645  Canada  British Columbia      Whistler     V6T 1Y8
# 12841          634916  Canada      Saskatchewan        Regina     S1J 3C5
# 4404           904669  Canada      Saskatchewan        Regina     S1J 3C5
# 14720          485258  Canada     New Brunswick   Fredericton     E3B 2H2
# 2566           434965  Canada          Manitoba      Winnipeg     R2C 0M5
# 15885          920792  Canada  British Columbia      Whistler     V6T 1Y8
# 6948           750384  Canada           Ontario       Toronto     P2T 6G3
# 2253           332855  Canada  British Columbia  Dawson Creek     U5I 4F1
# 15969          306708  Canada  British Columbia     Vancouver     V5R 1W3
#
#        Gender             Education   Salary Marital Status Loyalty Card  \
# 1800     Male               College      NaN         Single       Aurora
# 9940     Male               College      NaN         Single         Star
# 12841  Female               College      NaN        Married         Star
# 4404   Female              Bachelor  80846.0        Married         Nova
# 14720    Male              Bachelor  55093.0        Married         Star
# 2566   Female              Bachelor  75686.0        Married       Aurora
# 15885  Female               College      NaN         Single         Star
# 6948   Female              Bachelor  53464.0        Married         Nova
# 2253   Female              Bachelor  79367.0        Married       Aurora
# 15969  Female  High School or Below  50872.0        Married         Star
#
#             CLV Enrollment Type  Enrollment Year  Enrollment Month  \
# 1800    6732.20        Standard             2015                 3
# 9940    2195.30        Standard             2016                 4
# 12841   4504.16        Standard             2017                 5
# 4404    2846.65        Standard             2012                10
# 14720   7685.40        Standard             2017                 7
# 2566    8414.08        Standard             2018                12
# 15885  12520.98        Standard             2017                 4
# 6948    5754.85        Standard             2015                 1
# 2253    7739.55        Standard             2014                 4
# 15969  13269.60        Standard             2015                10
#
#        Cancellation Year  Cancellation Month
# 1800              2015.0                 6.0
# 9940                 NaN                 NaN
# 12841                NaN                 NaN
# 4404                 NaN                 NaN
# 14720             2018.0                 3.0
# 2566                 NaN                 NaN
# 15885                NaN                 NaN
# 6948                 NaN                 NaN
# 2253              2014.0                10.0
# 15969                NaN                 NaN

# %%
#Revisamos las dos últimas filas
df_loyalty.tail(2)
# Out:
#        Loyalty Number Country  Province        City Postal Code  Gender  \
# 16735          906428  Canada     Yukon  Whitehorse     Y2K 6R0    Male
# 16736          652627  Canada  Manitoba    Winnipeg     R2C 0M5  Female
#
#       Education   Salary Marital Status Loyalty Card       CLV  \
# 16735  Bachelor -57297.0        Married         Star  10018.66
# 16736  Bachelor  75049.0        Married         Star  83325.38
#
#       Enrollment Type  Enrollment Year  Enrollment Month  Cancellation Year  \
# 16735  2018 Promotion             2018                 4                NaN
# 16736        Standard             2015                12             2016.0
#
#        Cancellation Month
# 16735                 NaN
# 16736                 8.0

# %%
# No aparecen todas las columnas pues al devolvernos datos estadísticos, nos muestra sólo aquellas con valores numéricos
df_loyalty.describe().T
# Out:
#                       count           mean            std        min  \
# Loyalty Number      16737.0  549735.880445  258912.132453  100018.00
# Salary              12499.0   79245.609409   35008.297285  -58486.00
# CLV                 16737.0    7988.896536    6860.982280    1898.01
# Enrollment Year     16737.0    2015.253211       1.979111    2012.00
# Enrollment Month    16737.0       6.669116       3.398958       1.00
# Cancellation Year    2067.0    2016.503145       1.380743    2013.00
# Cancellation Month   2067.0       6.962748       3.455297       1.00
#
#                           25%        50%        75%        max
# Loyalty Number      326603.00  550434.00  772019.00  999986.00
# Salary               59246.50   73455.00   88517.50  407228.00
# CLV                   3980.84    5780.18    8940.58   83325.38
# Enrollment Year       2014.00    2015.00    2017.00    2018.00
# Enrollment Month         4.00       7.00      10.00      12.00
# Cancellation Year     2016.00    2017.00    2018.00    2018.00
# Cancellation Month       4.00       7.00      10.00      12.00

# %%
# Revisamos ahora los datos estadísitcos de las variables categóricas indicándole dicho filtro
df_loyalty.describe(include='object').T
# Out:
#                  count unique       top   freq
# Country          16737      1    Canada  16737
# Province         16737     11   Ontario   5404
# City             16737     29   Toronto   3351
# Postal Code      16737     55   V6E 3D9    911
# Gender           16737      2    Female   8410
# Education        16737      5  Bachelor  10475
# Marital Status   16737      3   Married   9735
# Loyalty Card     16737      3      Star   7637
# Enrollment Type  16737      2  Standard  15766

# %%
# Vamos a revisar los valores únicos de la columna EDUCATION, LOYALTY CARD y ENROLLMENT TYPE
print(f'Las opciones de la variable Education son: {df_loyalty["Education"].unique()}.')
print(f'Las opciones de la variable Loyalty card son: {df_loyalty["Loyalty Card"].unique()}.')
print(f'Las opciones de la variable Enrollment type son: {df_loyalty["Enrollment Type"].unique()}.')
# Out:
# Las opciones de la variable Education son: ['Bachelor' 'College' 'Master' 'High School or Below' 'Doctor'].
# Las opciones de la variable Loyalty card son: ['Star' 'Aurora' 'Nova'].
# Las opciones de la variable Enrollment type son: ['Standard' '2018 Promotion'].

# %%
# Revisamos la frecuencia de cada valor de la variable EDUCATION
df_loyalty['Education'].value_counts()
# Out:
# Education
# Bachelor                10475
# College                  4238
# High School or Below      782
# Doctor                    734
# Master                    508
# Name: count, dtype: int64

# %%
# Para revisar valores únicos y sus frecuencias de todas las variables categóricas usamos un bucle for. Para hacer más sencillo el uso del bucle,
# voy a realizar antes algunos ajustes. Selecciono todas las variables categóricas y lo añado en una nueva variable para poder trabajar mejor
df_loyalty_cat = df_loyalty.select_dtypes(include='object')
df_loyalty_cat.head(2)
# Out:
#   Country Province      City Postal Code  Gender Education Marital Status  \
# 0  Canada  Ontario   Toronto     M2Z 4K1  Female  Bachelor        Married
# 1  Canada  Alberta  Edmonton     T3G 6Y6    Male   College       Divorced
#
#   Loyalty Card Enrollment Type
# 0         Star        Standard
# 1         Star        Standard

# %%
# Elimino las columnas que no son de mi interés usando el método '.drop()', en este caso la columna del CP
df_loyalty_cat_drop = df_loyalty_cat.drop('Postal Code', axis=1, inplace=False)
df_loyalty_cat_drop
# Out:
#       Country          Province        City  Gender Education Marital Status  \
# 0      Canada           Ontario     Toronto  Female  Bachelor        Married
# 1      Canada           Alberta    Edmonton    Male   College       Divorced
# 2      Canada  British Columbia   Vancouver    Male   College         Single
# 3      Canada           Ontario     Toronto    Male   College         Single
# 4      Canada            Quebec        Hull    Male  Bachelor        Married
# ...       ...               ...         ...     ...       ...            ...
# 16732  Canada  British Columbia   Vancouver  Female   College        Married
# 16733  Canada      Saskatchewan      Regina  Female  Bachelor        Married
# 16734  Canada  British Columbia   Vancouver    Male   College         Single
# 16735  Canada             Yukon  Whitehorse    Male  Bachelor        Married
# 16736  Canada          Manitoba    Winnipeg  Female  Bachelor        Married
#
#       Loyalty Card Enrollment Type
# 0             Star        Standard
# 1             Star        Standard
# 2             Star        Standard
# 3             Star        Standard
# 4             Star        Standard
# ...            ...             ...
# 16732         Star        Standard
# 16733         Star        Standard
# 16734         Star        Standard
# 16735         Star  2018 Promotion
# 16736         Star        Standard
#
# [16737 rows x 8 columns]

# %%
# Para utilizar unique() y value_counts() en un bucle for, crearé primero una variable con las columnas del DF
columnas_cat = df_loyalty_cat_drop.columns
print(f"Las columnas del DataFrame de variables categóricas son {columnas_cat}")
# Out:
# Las columnas del DataFrame de variables categóricas son Index(['Country', 'Province', 'City', 'Gender', 'Education', 'Marital Status',
#        'Loyalty Card', 'Enrollment Type'],
#       dtype='object')

# %%
# Con el bucle for, iteramos por cada una de las columnas para, ahora sí, sacar sus valores únicos y sus frecuencias

for columna in columnas_cat:
    resultado_u = df_loyalty_cat_drop[columna].unique()
    resultado_c = df_loyalty_cat_drop[columna].value_counts()
    print(f"Columna: {columna}")
    print(f"Valores únicos: {resultado_u}")
    print(f"Frecuencias de dichos valores: \n{resultado_c}\n")
# Out:
# Columna: Country
# Valores únicos: ['Canada']
# Frecuencias de dichos valores:
# Country
# Canada    16737
# Name: count, dtype: int64
#
# Columna: Province
# Valores únicos: ['Ontario' 'Alberta' 'British Columbia' 'Quebec' 'Yukon' 'New Brunswick'
#  'Manitoba' 'Nova Scotia' 'Saskatchewan' 'Newfoundland'
#  'Prince Edward Island']
# Frecuencias de dichos valores:
# Province
# Ontario                 5404
# British Columbia        4409
# Quebec                  3300
# Alberta                  969
# Manitoba                 658
# New Brunswick            636
# Nova Scotia              518
# Saskatchewan             409
# Newfoundland             258
# Yukon                    110
# Prince Edward Island      66
# Name: count, dtype: int64
#
# Columna: City
# Valores únicos: ['Toronto' 'Edmonton' 'Vancouver' 'Hull' 'Whitehorse' 'Trenton' 'Montreal'
#  'Dawson Creek' 'Quebec City' 'Fredericton' 'Ottawa' 'Tremblant' 'Calgary'
#  'Thunder Bay' 'Whistler' 'Peace River' 'Winnipeg' 'Sudbury'
#  'West Vancouver' 'Halifax' 'London' 'Regina' 'Kelowna' "St. John's"
#  'Victoria' 'Kingston' 'Banff' 'Moncton' 'Charlottetown']
# Frecuencias de dichos valores:
# City
# Toronto           3351
# Vancouver         2582
# Montreal          2059
# Winnipeg           658
# Whistler           582
# Halifax            518
# Ottawa             509
# Trenton            486
# Edmonton           486
# Quebec City        485
# Dawson Creek       444
# Fredericton        425
# Regina             409
# Kingston           401
# Tremblant          398
# Victoria           389
# Hull               358
# West Vancouver     324
# St. John's         258
# Thunder Bay        256
# Sudbury            227
# Moncton            211
# Calgary            191
# Banff              179
# London             174
# Peace River        113
# Whitehorse         110
# Kelowna             88
# Charlottetown       66
# Name: count, dtype: int64
#
# Columna: Gender
# Valores únicos: ['Female' 'Male']
# Frecuencias de dichos valores:
# Gender
# Female    8410
# Male      8327
# Name: count, dtype: int64
#
# Columna: Education
# Valores únicos: ['Bachelor' 'College' 'Master' 'High School or Below' 'Doctor']
# Frecuencias de dichos valores:
# Education
# Bachelor                10475
# College                  4238
# High School or Below      782
# Doctor                    734
# Master                    508
# Name: count, dtype: int64
#
# Columna: Marital Status
# Valores únicos: ['Married' 'Divorced' 'Single']
# Frecuencias de dichos valores:
# Marital Status
# Married     9735
# Single      4484
# Divorced    2518
# Name: count, dtype: int64
#
# Columna: Loyalty Card
# Valores únicos: ['Star' 'Aurora' 'Nova']
# Frecuencias de dichos valores:
# Loyalty Card
# Star      7637
# Nova      5671
# Aurora    3429
# Name: count, dtype: int64
#
# Columna: Enrollment Type
# Valores únicos: ['Standard' '2018 Promotion']
# Frecuencias de dichos valores:
# Enrollment Type
# Standard          15766
# 2018 Promotion      971
# Name: count, dtype: int64

# %% [markdown]
# ### REVISIÓN DE VALORES NULOS ###

# %%
# Revisamos en qué columnas de nuestros DFs hay valores nulos 
df_flight.isnull().sum()

#Podríamos usuar también el método '.isna()' de Pandas para hallar los nulos
# Out:
# Loyalty Number                 0
# Year                           0
# Month                          0
# Flights Booked                 0
# Flights with Companions        0
# Total Flights                  0
# Distance                       0
# Points Accumulated             0
# Points Redeemed                0
# Dollar Cost Points Redeemed    0
# dtype: int64

# %%
# Entre otra info, vemos el total de datos NO NULOS
df_flight.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 405624 entries, 0 to 405623
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Loyalty Number               405624 non-null  int64
#  1   Year                         405624 non-null  int64
#  2   Month                        405624 non-null  int64
#  3   Flights Booked               405624 non-null  int64
#  4   Flights with Companions      405624 non-null  int64
#  5   Total Flights                405624 non-null  int64
#  6   Distance                     405624 non-null  int64
#  7   Points Accumulated           405624 non-null  float64
#  8   Points Redeemed              405624 non-null  int64
#  9   Dollar Cost Points Redeemed  405624 non-null  int64
# dtypes: float64(1), int64(9)
# memory usage: 30.9 MB

# %%
df_loyalty.isnull().sum()
# Out:
# Loyalty Number            0
# Country                   0
# Province                  0
# City                      0
# Postal Code               0
# Gender                    0
# Education                 0
# Salary                 4238
# Marital Status            0
# Loyalty Card              0
# CLV                       0
# Enrollment Type           0
# Enrollment Year           0
# Enrollment Month          0
# Cancellation Year     14670
# Cancellation Month    14670
# dtype: int64

# %%
df_loyalty.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16737 entries, 0 to 16736
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Loyalty Number      16737 non-null  int64
#  1   Country             16737 non-null  object
#  2   Province            16737 non-null  object
#  3   City                16737 non-null  object
#  4   Postal Code         16737 non-null  object
#  5   Gender              16737 non-null  object
#  6   Education           16737 non-null  object
#  7   Salary              12499 non-null  float64
#  8   Marital Status      16737 non-null  object
#  9   Loyalty Card        16737 non-null  object
#  10  CLV                 16737 non-null  float64
#  11  Enrollment Type     16737 non-null  object
#  12  Enrollment Year     16737 non-null  int64
#  13  Enrollment Month    16737 non-null  int64
#  14  Cancellation Year   2067 non-null   float64
#  15  Cancellation Month  2067 non-null   float64
# dtypes: float64(4), int64(3), object(9)
# memory usage: 2.0+ MB

# %%
# Solo tenemos nulos en el DF LOYALTY en las columnas: Salary, Cancellation Year y Cancellation Month

# Podemos calcular el porcentaje de nulos que tenemos para cada columna
porc_nulos = (df_loyalty.isnull().sum() / df_loyalty.shape[0]) * 100
porc_nulos
# Out:
# Loyalty Number         0.000000
# Country                0.000000
# Province               0.000000
# City                   0.000000
# Postal Code            0.000000
# Gender                 0.000000
# Education              0.000000
# Salary                25.321145
# Marital Status         0.000000
# Loyalty Card           0.000000
# CLV                    0.000000
# Enrollment Type        0.000000
# Enrollment Year        0.000000
# Enrollment Month       0.000000
# Cancellation Year     87.650117
# Cancellation Month    87.650117
# dtype: float64

# %%
# Quiero ver el número total de valores (en el DF y en cada columna) además de los pocentajes
# Calculo el número total de valores en la columna 'Salary', en ambas columnas Cancellation así como en todo el DF
total_valores_df = df_loyalty.size
total_valores_salario = df_loyalty['Salary'].size
total_valores_cancelacion = df_loyalty['Cancellation Month'].size

# Calculo el número total de valores nulos en la columna 'Salary', en ambas columnas Cancellation así como en todo el DF
total_nulos_df = df_loyalty.isnull().sum().sum()
total_nulos_salario = df_loyalty['Salary'].isnull().sum()
total_nulos_cancelacion = df_loyalty['Cancellation Month'].isnull().sum()

# Calculo el porcentaje de valores nulos en la columna 'Salary', en ambas columnas Cancellation así como en todo el DF
porcentaje_nulos_df = (total_nulos_df / total_valores_df) * 100
porcentaje_nulos_salary = (total_nulos_salario / total_valores_salario) * 100
porcentaje_nulos_cancelacion = (total_nulos_cancelacion / total_valores_cancelacion) * 100

print(f'El total de valores nulos en todo el DF es de {total_nulos_df}, es decir, el porcentaje de nulos en todo el DF es del {porcentaje_nulos_df.round()}')
print(f'El número total de valores de la columna Salary es de {total_valores_salario} y de las columnas Cancellation (year,month) también es de {total_valores_cancelacion}')
print(f'El total de valores nulos en la columna Salary es de {total_nulos_salario}, es decir, el porcentaje es del {porcentaje_nulos_salary.round()}')
print(f'El total de valores nulos en cada columna Cancellation (month, year) es de {total_nulos_cancelacion}, es decir, el porcentaje es del {porcentaje_nulos_cancelacion.round()}')
# Out:
# El total de valores nulos en todo el DF es de 33578, es decir, el porcentaje de nulos en todo el DF es del 13.0
# El número total de valores de la columna Salary es de 16737 y de las columnas Cancellation (year,month) también es de 16737
# El total de valores nulos en la columna Salary es de 4238, es decir, el porcentaje es del 25.0
# El total de valores nulos en cada columna Cancellation (month, year) es de 14670, es decir, el porcentaje es del 88.0

# %% [markdown]
# ##### Observo que los datos nulos en las columnas 'Cancellation' son las personas que no han cancelado, es decir, actuales clientes. Respecto a los nulos en 'Salary', tendré que hacer un estudio más exhaustivo.

# %%
# Para ver valores atípicos en las columnas donde tenemos nulos (sin visualización)
# Librerías de visualización
import seaborn as sns
import matplotlib.pyplot as plt

nulos_esta_num = df_loyalty[df_loyalty.columns[df_loyalty.isnull().any()]].select_dtypes(include = np.number).columns
fig, axes = plt.subplots(nrows = 2, ncols = 3, figsize = (20,10)) 

axes = axes.flat

for indice, col in enumerate(nulos_esta_num):
    sns.boxplot(x = col, data = df_loyalty, ax = axes[indice])
    
plt.tight_layout()
fig.delaxes(axes[-1]);

# %% [markdown]
# ##### Como podemos ver, en la columna 'Salary' hay muchos valores atípicos. Cuando vayamos a gestionr los nulos, tendremos que ver si estos valores son reales o se trata de un posible error #####

# %% [markdown]
# ### REVISIÓN DE VALORES DUPLICADOS ###

# %%
# Igual que el método '.isnull()', '.duplicated()' devuelve valores booleanos de todo el DF. Hacemos sumatorio
df_flight.duplicated().sum()
# Out:
# 1864

# %%
# ¿En qué filas/columnas tenemos los datos duplicados?
df_flight_dup = df_flight[df_flight.duplicated()]
df_flight_dup
# Out:
#         Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 42              101902  2017      1               0                        0
# 227             112142  2017      1               0                        0
# 478             126100  2017      1               0                        0
# 567             130331  2017      1               0                        0
# 660             135421  2017      1               0                        0
# ...                ...   ...    ...             ...                      ...
# 404668          949628  2018     12               0                        0
# 404884          960050  2018     12               0                        0
# 405111          971370  2018     12               0                        0
# 405410          988392  2018     12               0                        0
# 405437          989528  2018     12               0                        0
#
#         Total Flights  Distance  Points Accumulated  Points Redeemed  \
# 42                  0         0                 0.0                0
# 227                 0         0                 0.0                0
# 478                 0         0                 0.0                0
# 567                 0         0                 0.0                0
# 660                 0         0                 0.0                0
# ...               ...       ...                 ...              ...
# 404668              0         0                 0.0                0
# 404884              0         0                 0.0                0
# 405111              0         0                 0.0                0
# 405410              0         0                 0.0                0
# 405437              0         0                 0.0                0
#
#         Dollar Cost Points Redeemed
# 42                                0
# 227                               0
# 478                               0
# 567                               0
# 660                               0
# ...                             ...
# 404668                            0
# 404884                            0
# 405111                            0
# 405410                            0
# 405437                            0
#
# [1864 rows x 10 columns]

# %%
# Observo que existen duplicados en la columna Loyalty Number, lo cual deseo revisar en profundidad pues se trata de un identificador único para cada cliente.
# Reviso un poco más los duplicados de la columna, es decir, que valores se repiten y cuantas veces. 

loyalty_numbers_dup = df_flight['Loyalty Number'].value_counts()
loyalty_numbers_dup
# Out:
# Loyalty Number
# 678205    72
# 989528    48
# 373638    48
# 684889    48
# 684881    48
#           ..
# 428526    24
# 428536    24
# 428565    24
# 428590    24
# 999891    24
# Name: count, Length: 16737, dtype: int64

# %%
# Continúo con la revisión, quiero inspeccionar las filas con valores de Loyalty Number duplicadas para ver si es correcto o se son filas completas duplicadas

# Filtro las filas que tienen Loyalty Number duplicados
duplicated_rows = df_flight[df_flight['Loyalty Number'].isin(loyalty_numbers_dup.index)]

# Ordeno las filas duplicadas por Loyalty Number para estudiarlo mejor
duplicated_rows_sorted = duplicated_rows.sort_values(by='Loyalty Number')
print(duplicated_rows_sorted)
# Out:
#         Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 0               100018  2017      1               3                        0
# 388723          100018  2018     12              17                        6
# 185911          100018  2017     12               6                        0
# 101406          100018  2017      7              10                        0
# 287317          100018  2018      6               0                        0
# ...                ...   ...    ...             ...                      ...
# 304217          999986  2018      6               0                        0
# 321118          999986  2018      7              15                        0
# 354920          999986  2018      9               0                        0
# 185910          999986  2017     11               0                        0
# 405623          999986  2018     12               0                        0
#
#         Total Flights  Distance  Points Accumulated  Points Redeemed  \
# 0                   3      1521               152.0                0
# 388723             23      4945               494.0                0
# 185911              6      1908               190.0                0
# 101406             10      3870               387.0                0
# 287317              0         0                 0.0                0
# ...               ...       ...                 ...              ...
# 304217              0         0                 0.0                0
# 321118             15      1995               199.0                0
# 354920              0         0                 0.0                0
# 185910              0         0                 0.0                0
# 405623              0         0                 0.0                0
#
#         Dollar Cost Points Redeemed
# 0                                 0
# 388723                            0
# 185911                            0
# 101406                            0
# 287317                            0
# ...                             ...
# 304217                            0
# 321118                            0
# 354920                            0
# 185910                            0
# 405623                            0
#
# [405624 rows x 10 columns]

# %% [markdown]
# Compruebo que se repite el Loyalty number puesto que algunes clientes han volado en diferentes años y meses, no son filas duplicadas por error.

# %%
# Igual que el método '.isnull()', devuelve valores booleanos de todo el DF. Hacemos sumatorio
df_loyalty.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### UNIÓN DE LOS DATA FRAME ###

# %%
# Debido a que poseemos una columna en común en ambos DF (Loyalty Number, Identificador único del cliente dentro 
# del programa de lealtad), vamos a usar el método 'merge()' 
# Primero recordemos como son nuestros DFs
df_flight.head(2)
# Out:
#    Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 0          100018  2017      1               3                        0
# 1          100102  2017      1              10                        4
#
#    Total Flights  Distance  Points Accumulated  Points Redeemed  \
# 0              3      1521               152.0                0
# 1             14      2030               203.0                0
#
#    Dollar Cost Points Redeemed
# 0                            0
# 1                            0

# %%
df_loyalty.head(2)
# Out:
#    Loyalty Number Country Province      City Postal Code  Gender Education  \
# 0          480934  Canada  Ontario   Toronto     M2Z 4K1  Female  Bachelor
# 1          549612  Canada  Alberta  Edmonton     T3G 6Y6    Male   College
#
#     Salary Marital Status Loyalty Card      CLV Enrollment Type  \
# 0  83236.0        Married         Star  3839.14        Standard
# 1      NaN       Divorced         Star  3839.61        Standard
#
#    Enrollment Year  Enrollment Month  Cancellation Year  Cancellation Month
# 0             2016                 2                NaN                 NaN
# 1             2016                 3                NaN                 NaN

# %%
# Unión de los DFs con 'merge/outer pues deseo que me devuelva todos los valores (comunes y no comunes)
df_union = df_loyalty.merge(df_flight, how='outer', on='Loyalty Number')
df_union.head(2)
# Out:
#    Loyalty Number Country Province      City Postal Code  Gender Education  \
# 0          100018  Canada  Alberta  Edmonton     T9G 1W3  Female  Bachelor
# 1          100018  Canada  Alberta  Edmonton     T9G 1W3  Female  Bachelor
#
#     Salary Marital Status Loyalty Card     CLV Enrollment Type  \
# 0  92552.0        Married       Aurora  7919.2        Standard
# 1  92552.0        Married       Aurora  7919.2        Standard
#
#    Enrollment Year  Enrollment Month  Cancellation Year  Cancellation Month  \
# 0             2016                 8                NaN                 NaN
# 1             2016                 8                NaN                 NaN
#
#    Year  Month  Flights Booked  Flights with Companions  Total Flights  \
# 0  2017      1               3                        0              3
# 1  2017      2               2                        2              4
#
#    Distance  Points Accumulated  Points Redeemed  Dollar Cost Points Redeemed
# 0      1521               152.0                0                            0
# 1      1320               132.0                0                            0

# %% [markdown]
# ///////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////

# %% [markdown]
# ## 2. LIMPIEZA DE DATOS ##

# %% [markdown]
# ##### Respeto a la limpieza del formato tanto de nombres de columnas como de los valores, nuestro DF es homogéneo por lo que no realizaré nigún cambio. ####

# %% [markdown]
# ##### Para tratar los datos nulos, recordemos que tan solo aparecían en el DF LOYALTY en las columnas: Salary, Cancellation Year y Cancellation Month. Tras revisar los procesos de estudio y visualización de datos que debo realizar tras la limpieza, observo que las columnas Cancellation Year y Cancellation Month no las voy a necesitar, por lo que las eliminaré (tal y como hice con la columna Postal Code para trabajar mejor) creando un nuevo DF. #####

# %%
# Eliminación de columnas que contienen nulos y que no voy a necesitar
df_union_clean3 = df_union.drop(df_union[['Cancellation Year', 'Cancellation Month']], axis=1, inplace=False)
df_union_clean3
# Out:
#         Loyalty Number Country Province      City Postal Code  Gender  \
# 0               100018  Canada  Alberta  Edmonton     T9G 1W3  Female
# 1               100018  Canada  Alberta  Edmonton     T9G 1W3  Female
# 2               100018  Canada  Alberta  Edmonton     T9G 1W3  Female
# 3               100018  Canada  Alberta  Edmonton     T9G 1W3  Female
# 4               100018  Canada  Alberta  Edmonton     T9G 1W3  Female
# ...                ...     ...      ...       ...         ...     ...
# 405619          999986  Canada  Ontario    Ottawa     K1F 2R2  Female
# 405620          999986  Canada  Ontario    Ottawa     K1F 2R2  Female
# 405621          999986  Canada  Ontario    Ottawa     K1F 2R2  Female
# 405622          999986  Canada  Ontario    Ottawa     K1F 2R2  Female
# 405623          999986  Canada  Ontario    Ottawa     K1F 2R2  Female
#
#        Education   Salary Marital Status Loyalty Card      CLV  \
# 0       Bachelor  92552.0        Married       Aurora  7919.20
# 1       Bachelor  92552.0        Married       Aurora  7919.20
# 2       Bachelor  92552.0        Married       Aurora  7919.20
# 3       Bachelor  92552.0        Married       Aurora  7919.20
# 4       Bachelor  92552.0        Married       Aurora  7919.20
# ...          ...      ...            ...          ...      ...
# 405619  Bachelor  46594.0        Married         Nova  8257.01
# 405620  Bachelor  46594.0        Married         Nova  8257.01
# 405621  Bachelor  46594.0        Married         Nova  8257.01
# 405622  Bachelor  46594.0        Married         Nova  8257.01
# 405623  Bachelor  46594.0        Married         Nova  8257.01
#
#        Enrollment Type  Enrollment Year  Enrollment Month  Year  Month  \
# 0             Standard             2016                 8  2017      1
# 1             Standard             2016                 8  2017      2
# 2             Standard             2016                 8  2018     10
# 3             Standard             2016                 8  2017      4
# 4             Standard             2016                 8  2017      5
# ...                ...              ...               ...   ...    ...
# 405619  2018 Promotion             2018                 2  2018      7
# 405620  2018 Promotion             2018                 2  2018      9
# 405621  2018 Promotion             2018                 2  2018     10
# 405622  2018 Promotion             2018                 2  2018     11
# 405623  2018 Promotion             2018                 2  2018     12
#
#         Flights Booked  Flights with Companions  Total Flights  Distance  \
# 0                    3                        0              3      1521
# 1                    2                        2              4      1320
# 2                    6                        4             10      3110
# 3                    4                        0              4       924
# 4                    0                        0              0         0
# ...                ...                      ...            ...       ...
# 405619              15                        0             15      1995
# 405620               0                        0              0         0
# 405621               6                        0              6       708
# 405622              11                        4             15      2040
# 405623               0                        0              0         0
#
#         Points Accumulated  Points Redeemed  Dollar Cost Points Redeemed
# 0                    152.0                0                            0
# 1                    132.0                0                            0
# 2                    311.0              385                           31
# 3                     92.0                0                            0
# 4                      0.0                0                            0
# ...                    ...              ...                          ...
# 405619               199.0                0                            0
# 405620                 0.0                0                            0
# 405621                70.0                0                            0
# 405622               204.0                0                            0
# 405623                 0.0                0                            0
#
# [405624 rows x 23 columns]

# %%
# Revisando la tabla, vemos que todavía hay información innecesaria para nuestro trabajo de análisis, por lo que vamos a prescindir de ella para tener 
# un DF más limpio y que se vea más clara la información. 
# Variables que sí necesito: Loyalty Number, Province, Gender, Education, Salary, Marital Status, Loyalty Card, Year, Month, Flights Booked, 
# Distance, Points Accumulated

df_union_clean2 = df_union_clean3.drop(df_union[['Postal Code','Country', 'City', 'CLV', 'Enrollment Type', 'Enrollment Year', 'Enrollment Month', 'Flights with Companions', 'Points Redeemed', 'Dollar Cost Points Redeemed']], axis=1, inplace=False)
df_union_clean2.head(2)
# Out:
#    Loyalty Number Province  Gender Education   Salary Marital Status  \
# 0          100018  Alberta  Female  Bachelor  92552.0        Married
# 1          100018  Alberta  Female  Bachelor  92552.0        Married
#
#   Loyalty Card  Year  Month  Flights Booked  Total Flights  Distance  \
# 0       Aurora  2017      1               3              3      1521
# 1       Aurora  2017      2               2              4      1320
#
#    Points Accumulated
# 0               152.0
# 1               132.0

# %%
df_union_clean2.sample(10)
# Out:
#         Loyalty Number          Province  Gender             Education  \
# 147228          428604  British Columbia  Female                Master
# 333257          837327            Quebec  Female              Bachelor
# 274005          707513           Ontario    Male              Bachelor
# 285360          732304            Quebec    Male              Bachelor
# 371906          924878            Quebec    Male              Bachelor
# 340220          852863  British Columbia  Female  High School or Below
# 144551          423153            Quebec  Female              Bachelor
# 266982          691700  British Columbia  Female               College
# 19220           142290           Alberta    Male               College
# 6641            114414           Ontario    Male               College
#
#          Salary Marital Status Loyalty Card  Year  Month  Flights Booked  \
# 147228  94440.0       Divorced         Nova  2018      1               0
# 333257  99726.0       Divorced         Nova  2018      6               0
# 274005  83582.0        Married         Star  2018     10               1
# 285360  82727.0        Married         Nova  2017      1               0
# 371906  58318.0        Married         Nova  2017      3               0
# 340220  39632.0        Married         Star  2018      8              10
# 144551  56042.0        Married         Nova  2018     12               0
# 266982      NaN         Single         Star  2017      8              13
# 19220       NaN       Divorced         Star  2018      9               7
# 6641        NaN        Married         Nova  2018      9               4
#
#         Total Flights  Distance  Points Accumulated
# 147228              0         0                 0.0
# 333257              0         0                 0.0
# 274005              2      2430               243.0
# 285360              0         0                 0.0
# 371906              0         0                 0.0
# 340220             14      2548               254.0
# 144551              0         0                 0.0
# 266982             13      2756               275.0
# 19220              11      2750               275.0
# 6641                4      1344               134.0

# %%
# Revisaré los datos estadísticos
df_union_clean2.describe().T
# Out:
#                        count           mean            std       min  \
# Loyalty Number      405624.0  550037.873084  258935.286969  100018.0
# Salary              302952.0   79268.825953   34992.133508  -58486.0
# Year                405624.0    2017.500000       0.500001    2017.0
# Month               405624.0       6.500000       3.452057       1.0
# Flights Booked      405624.0       4.115052       5.225518       0.0
# Total Flights       405624.0       5.146858       6.521227       0.0
# Distance            405624.0    1208.880059    1433.155320       0.0
# Points Accumulated  405624.0     123.692721     146.599831       0.0
#
#                           25%       50%        75%       max
# Loyalty Number      326961.00  550834.0  772194.00  999986.0
# Salary               59262.00   73479.0   88612.00  407228.0
# Year                  2017.00    2017.5    2018.00    2018.0
# Month                    3.75       6.5       9.25      12.0
# Flights Booked           0.00       1.0       8.00      21.0
# Total Flights            0.00       1.0      10.00      32.0
# Distance                 0.00     488.0    2336.00    6293.0
# Points Accumulated       0.00      50.0     239.00     676.5

# %%
# Cómo podemos observar, la columna Salary tiene un valor mínimo negativo, lo cual no es posible porque estamos revisando 
# el salario que perciben les clientes, por lo que deduzco que debe ser un error. Vamos a revisar los números negativos existentes

columna_s = df_union_clean2['Salary']
contador = 0
for num in columna_s:
    if num < 0:
            # si encuentra valor; lo paso a número y lo pinto soi es negativo
        contador += 1
        print(num)

print(f"Número de valores negativos en 'Salary': {contador}")
# Out:
# -10605.0
# -10605.0
# -10605.0
# -10605.0
# -10605.0
# -10605.0
# -10605.0
# -10605.0
# -10605.0
# -10605.0
# -10605.0
# -10605.0
# -10605.0
# -10605.0
# -10605.0
# -10605.0
# -10605.0
# -10605.0
# -10605.0
# -10605.0
# -10605.0
# -10605.0
# -10605.0
# -10605.0
# -58486.0
# -58486.0
# -58486.0
# -58486.0
# -58486.0
# -58486.0
# -58486.0
# -58486.0
# -58486.0
# -58486.0
# -58486.0
# -58486.0
# -58486.0
# -58486.0
# -58486.0
# -58486.0
# -58486.0
# -58486.0
# -58486.0
# -58486.0
# -58486.0
# -58486.0
# -58486.0
# -58486.0
# -31911.0
# -31911.0
# -31911.0
# -31911.0
# -31911.0
# -31911.0
# -31911.0
# -31911.0
# -31911.0
# -31911.0
# -31911.0
# -31911.0
# -31911.0
# -31911.0
# -31911.0
# -31911.0
# -31911.0
# -31911.0
# -31911.0
# -31911.0
# -31911.0
# -31911.0
# -31911.0
# -31911.0
# -49001.0
# -49001.0
# -49001.0
# -49001.0
# -49001.0
# -49001.0
# -49001.0
# -49001.0
# -49001.0
# -49001.0
# -49001.0
# -49001.0
# -49001.0
# -49001.0
# -49001.0
# -49001.0
# -49001.0
# -49001.0
# -49001.0
# -49001.0
# -49001.0
# -49001.0
# -49001.0
# -49001.0
# -46683.0
# -46683.0
# -46683.0
# -46683.0
# -46683.0
# -46683.0
# -46683.0
# -46683.0
# -46683.0
# -46683.0
# -46683.0
# -46683.0
# -46683.0
# -46683.0
# -46683.0
# -46683.0
# -46683.0
# -46683.0
# -46683.0
# -46683.0
# -46683.0
# -46683.0
# -46683.0
# -46683.0
# -47310.0
# -47310.0
# -47310.0
# -47310.0
# -47310.0
# -47310.0
# -47310.0
# -47310.0
# -47310.0
# -47310.0
# -47310.0
# -47310.0
# -47310.0
# -47310.0
# -47310.0
# -47310.0
# -47310.0
# -47310.0
# -47310.0
# -47310.0
# -47310.0
# -47310.0
# -47310.0
# -47310.0
# -39503.0
# -39503.0
# -39503.0
# -39503.0
# -39503.0
# -39503.0
# -39503.0
# -39503.0
# -39503.0
# -39503.0
# -39503.0
# -39503.0
# -39503.0
# -39503.0
# -39503.0
# -39503.0
# -39503.0
# -39503.0
# -39503.0
# -39503.0
# -39503.0
# -39503.0
# -39503.0
# -39503.0
# -26322.0
# -26322.0
# -26322.0
# -26322.0
# -26322.0
# -26322.0
# -26322.0
# -26322.0
# -26322.0
# -26322.0
# -26322.0
# -26322.0
# -26322.0
# -26322.0
# -26322.0
# -26322.0
# -26322.0
# -26322.0
# -26322.0
# -26322.0
# -26322.0
# -26322.0
# -26322.0
# -26322.0
# -9081.0
# -9081.0
# -9081.0
# -9081.0
# -9081.0
# -9081.0
# -9081.0
# -9081.0
# -9081.0
# -9081.0
# -9081.0
# -9081.0
# -9081.0
# -9081.0
# -9081.0
# -9081.0
# -9081.0
# -9081.0
# -9081.0
# -9081.0
# -9081.0
# -9081.0
# -9081.0
# -9081.0
# -17534.0
# -17534.0
# -17534.0
# -17534.0
# -17534.0
# -17534.0
# -17534.0
# -17534.0
# -17534.0
# -17534.0
# -17534.0
# -17534.0
# -17534.0
# -17534.0
# -17534.0
# -17534.0
# -17534.0
# -17534.0
# -17534.0
# -17534.0
# -17534.0
# -17534.0
# -17534.0
# -17534.0
# -46470.0
# -46470.0
# -46470.0
# -46470.0
# -46470.0
# -46470.0
# -46470.0
# -46470.0
# -46470.0
# -46470.0
# -46470.0
# -46470.0
# -46470.0
# -46470.0
# -46470.0
# -46470.0
# -46470.0
# -46470.0
# -46470.0
# -46470.0
# -46470.0
# -46470.0
# -46470.0
# -46470.0
# -43234.0
# -43234.0
# -43234.0
# -43234.0
# -43234.0
# -43234.0
# -43234.0
# -43234.0
# -43234.0
# -43234.0
# -43234.0
# -43234.0
# -43234.0
# -43234.0
# -43234.0
# -43234.0
# -43234.0
# -43234.0
# -43234.0
# -43234.0
# -43234.0
# -43234.0
# -43234.0
# -43234.0
# -45962.0
# -45962.0
# -45962.0
# -45962.0
# -45962.0
# -45962.0
# -45962.0
# -45962.0
# -45962.0
# -45962.0
# -45962.0
# -45962.0
# -45962.0
# -45962.0
# -45962.0
# -45962.0
# -45962.0
# -45962.0
# -45962.0
# -45962.0
# -45962.0
# -45962.0
# -45962.0
# -45962.0
# -49830.0
# -49830.0
# -49830.0
# -49830.0
# -49830.0
# -49830.0
# -49830.0
# -49830.0
# -49830.0
# -49830.0
# -49830.0
# -49830.0
# -49830.0
# -49830.0
# -49830.0
# -49830.0
# -49830.0
# -49830.0
# -49830.0
# -49830.0
# -49830.0
# -49830.0
# -49830.0
# -49830.0
# -19325.0
# -19325.0
# -19325.0
# -19325.0
# -19325.0
# -19325.0
# -19325.0
# -19325.0
# -19325.0
# -19325.0
# -19325.0
# -19325.0
# -19325.0
# -19325.0
# -19325.0
# -19325.0
# -19325.0
# -19325.0
# -19325.0
# -19325.0
# -19325.0
# -19325.0
# -19325.0
# -19325.0
# -19332.0
# -19332.0
# -19332.0
# -19332.0
# -19332.0
# -19332.0
# -19332.0
# -19332.0
# -19332.0
# -19332.0
# -19332.0
# -19332.0
# -19332.0
# -19332.0
# -19332.0
# -19332.0
# -19332.0
# -19332.0
# -19332.0
# -19332.0
# -19332.0
# -19332.0
# -19332.0
# -19332.0
# -46303.0
# -46303.0
# -46303.0
# -46303.0
# -46303.0
# -46303.0
# -46303.0
# -46303.0
# -46303.0
# -46303.0
# -46303.0
# -46303.0
# -46303.0
# -46303.0
# -46303.0
# -46303.0
# -46303.0
# -46303.0
# -46303.0
# -46303.0
# -46303.0
# -46303.0
# -46303.0
# -46303.0
# -34079.0
# -34079.0
# -34079.0
# -34079.0
# -34079.0
# -34079.0
# -34079.0
# -34079.0
# -34079.0
# -34079.0
# -34079.0
# -34079.0
# -34079.0
# -34079.0
# -34079.0
# -34079.0
# -34079.0
# -34079.0
# -34079.0
# -34079.0
# -34079.0
# -34079.0
# -34079.0
# -34079.0
# -57297.0
# -57297.0
# -57297.0
# -57297.0
# -57297.0
# -57297.0
# -57297.0
# -57297.0
# -57297.0
# -57297.0
# -57297.0
# -57297.0
# -57297.0
# -57297.0
# -57297.0
# -57297.0
# -57297.0
# -57297.0
# -57297.0
# -57297.0
# -57297.0
# -57297.0
# -57297.0
# -57297.0
# -12497.0
# -12497.0
# -12497.0
# -12497.0
# -12497.0
# -12497.0
# -12497.0
# -12497.0
# -12497.0
# -12497.0
# -12497.0
# -12497.0
# -12497.0
# -12497.0
# -12497.0
# -12497.0
# -12497.0
# -12497.0
# -12497.0
# -12497.0
# -12497.0
# -12497.0
# -12497.0
# -12497.0
# Número de valores negativos en 'Salary': 480

# %%
# Vamos a eliminar el signo negativo de los 480 números negativos usando el método 'np.where'. No puedo usar la función 'abs() debido a los valores nulos
df_union_clean2_pos = df_union_clean2.copy() #Hago una copia por si más adelante decido que este método no es correcto
df_union_clean2_pos['Salary'] = np.where(df_union_clean2_pos['Salary'] < 0, df_union_clean2_pos['Salary']*-1, df_union_clean2_pos['Salary'])
#He multiplicado los nums negativos por -1 para convertirlos en positivo

# %%
# Comprobación:
columna_s2 = df_union_clean2_pos['Salary']
contador = 0
for num in columna_s2:
    if num < 0:
            # si encuentra valor; lo paso a número y lo pinto soi es negativo
        contador += 1
        print(num)

print(f"Número de valores negativos en 'Salary': {contador}")
# Out:
# Número de valores negativos en 'Salary': 0

# %%
# Revisamos los nuevos valores estadísticos
df_union_clean2_pos.describe().T
# Out:
#                        count           mean            std       min  \
# Loyalty Number      405624.0  550037.873084  258935.286969  100018.0
# Salary              302952.0   79381.440228   34735.904533    9081.0
# Year                405624.0    2017.500000       0.500001    2017.0
# Month               405624.0       6.500000       3.452057       1.0
# Flights Booked      405624.0       4.115052       5.225518       0.0
# Total Flights       405624.0       5.146858       6.521227       0.0
# Distance            405624.0    1208.880059    1433.155320       0.0
# Points Accumulated  405624.0     123.692721     146.599831       0.0
#
#                           25%       50%        75%       max
# Loyalty Number      326961.00  550834.0  772194.00  999986.0
# Salary               59262.00   73479.0   88612.00  407228.0
# Year                  2017.00    2017.5    2018.00    2018.0
# Month                    3.75       6.5       9.25      12.0
# Flights Booked           0.00       1.0       8.00      21.0
# Total Flights            0.00       1.0      10.00      32.0
# Distance                 0.00     488.0    2336.00    6293.0
# Points Accumulated       0.00      50.0     239.00     676.5

# %%
media_salario = df_union_clean2_pos['Salary'].mean() #la tenemos arriba pero quiero ver las 3 cifras juntas
moda_salario = df_union_clean2_pos['Salary'].mode()[0]
mediana_salario = df_union_clean2_pos['Salary'].median()

print(media_salario.round())
print(moda_salario.round())
print(mediana_salario.round())
# Out:
# 79381.0
# 101933.0
# 73479.0

# %%
# Reviso nuevamente los nulos tras mi limpieza
df_union_clean2_pos.isnull().sum()
# Out:
# Loyalty Number             0
# Province                   0
# Gender                     0
# Education                  0
# Salary                102672
# Marital Status             0
# Loyalty Card               0
# Year                       0
# Month                      0
# Flights Booked             0
# Total Flights              0
# Distance                   0
# Points Accumulated         0
# dtype: int64

# %%
df_union_clean2_pos.notnull().sum()
# Out:
# Loyalty Number        405624
# Province              405624
# Gender                405624
# Education             405624
# Salary                302952
# Marital Status        405624
# Loyalty Card          405624
# Year                  405624
# Month                 405624
# Flights Booked        405624
# Total Flights         405624
# Distance              405624
# Points Accumulated    405624
# dtype: int64

# %%
# Calculo el número total de valores en todo el DF y en la columna 'Salary' 
total_valores_df_c2 = df_union_clean2_pos.size
total_valores_salario_c2 = df_union_clean2_pos['Salary'].size

# Calculo el número total de valores nulos en todo el DF y en la columna 'Salary'
total_nulos_df_c2 = df_union_clean2_pos.isnull().sum().sum()
total_nulos_salario_c2 = df_union_clean2_pos['Salary'].isnull().sum()


# Calculo el porcentaje de valores nulos en la columna 'Salary', en ambas columnas Cancellation así como en todo el DF
porcentaje_nulos_df_c2 = (total_nulos_df_c2 / total_valores_df_c2) * 100
porcentaje_nulos_salario_c2 = (total_nulos_salario_c2 / total_valores_salario_c2) * 100

print(f'El número total de valores del DF es de {total_valores_df_c2}')
print(f'El número total de valores de la columna Salary es de {total_valores_salario_c2}')
print(f'El total de valores nulos en todo el DF es de {total_nulos_df_c2}, es decir, el porcentaje de nulos en todo el DF es del {porcentaje_nulos_df_c2.round()}%')
print(f'El total de valores nulos en la columna Salary es de {total_nulos_salario_c2}, es decir, el porcentaje de nulos respecto al total de valores solo en la columna Salary es del {porcentaje_nulos_salario_c2.round()}%')
print(f'El total de valores nulos del DF ({total_nulos_df_c2}) debe ser igual al total de nulos de la columna Salary ({total_nulos_salario_c2}) pues hemos eliminado las otras columnas con nulos')
# Out:
# El número total de valores del DF es de 5273112
# El número total de valores de la columna Salary es de 405624
# El total de valores nulos en todo el DF es de 102672, es decir, el porcentaje de nulos en todo el DF es del 2.0%
# El total de valores nulos en la columna Salary es de 102672, es decir, el porcentaje de nulos respecto al total de valores solo en la columna Salary es del 25.0%
# El total de valores nulos del DF (102672) debe ser igual al total de nulos de la columna Salary (102672) pues hemos eliminado las otras columnas con nulos

# %% [markdown]
# ##### Ahora que nuestra bbdd es más manejable, puedo revisar mejor la forma de finalizar el tratamiento de valores nulos (aún quedan en la columna Salary). Debido al alto porcentaje de valores nulos en la col 'Salary', no uso el método '.dropna()' para eliminar filas pues perdería demasiada información. Decido imputar los nulos. Me planteo la siguiente cuestión, ¿significan los nulos que les clientes no reciben salario o es un error de información o falta de ella? #####

# %%
# Reviso si existe alguna fila en la que el salario sea 0, pues eso significaría que si alguien no tiene salario, se ha indicado con una cifra numérica.
numero_de_ceros = (df_union_clean2_pos['Salary'] == 0).sum()
print(f"Hay {numero_de_ceros} ceros en la columna 'Salary'.")
# Out:
# Hay 0 ceros en la columna 'Salary'.

# %% [markdown]
# ##### Al no tener el valor 0 en ningún caso, debo plantearme si esos nulos son ausencia de salario (imputaría los NaN por 0) o si son errores/falta de información. Para terminar de tomar la decisión de sustituir por 0 o hacer otra acción, voy a explorar la columna en relación con otras mediante 'groupby'. #####

# %%
# Agrupar por Gender y calcular estadísticas descriptivas del salario: pienso que podría haber relación por la carga cultural de la mujer a no trabajr fuera 
# de casa para poder encargarse del hogar y todo lo que ello conlleva.
salary_by_gender = df_union_clean2_pos.groupby('Gender')['Salary'].describe()
salary_by_gender
# Out:
#            count          mean           std      min      25%      50%  \
# Gender
# Female  153072.0  79355.868454  34163.529699   9081.0  59265.0  73663.5
# Male    149880.0  79407.556605  35310.989060  10605.0  59262.0  73277.0
#
#             75%       max
# Gender
# Female  88978.0  407228.0
# Male    88270.0  381124.0

# %%
# Agrupar por Marital Status y calcular estadísticas descriptivas del salario: como el caso anterior, estar casade puede influir en la elección de no 
# trabajar mientras lo haga la pareja
salary_by_loyalty_card = df_union_clean2_pos.groupby('Marital Status')['Salary'].describe()
salary_by_loyalty_card
# Out:
#                    count          mean           std      min      25%  \
# Marital Status
# Divorced         52008.0  83752.066913  39793.294024  15609.0  60971.0
# Married         201072.0  78971.108140  34490.837992   9081.0  58936.0
# Single           49872.0  76477.982194  29205.049962  16628.0  58653.0
#
#                     50%      75%       max
# Marital Status
# Divorced        75079.0  91978.0  362833.0
# Married         73496.0  88120.0  407228.0
# Single          72022.5  86590.0  363189.0

# %%
# Agrupar por Education y calcular estadísticas descriptivas del salario: pienso que un nivel educativo más alto puede influir a la hora de tener trabajo, 
# al igual que estar estudiando dificulta la posiblidad e trabajar y recibir un salario. 
salary_by_education = df_union_clean2_pos.groupby('Education')['Salary'].describe()
salary_by_education
# Out:
#                          count           mean           std      min  \
# Education
# Bachelor              253752.0   72601.235033  16670.286198   9081.0
# College                    0.0            NaN           NaN      NaN
# Doctor                 17856.0  178335.439516  70307.642502  48109.0
# High School or Below   19008.0   61112.377525  12105.086402  21853.0
# Master                 12336.0  103767.494163  17514.343573  56414.0
#
#                             25%       50%        75%       max
# Education
# Bachelor               58711.00   71971.0   85848.00  105563.0
# College                     NaN       NaN        NaN       NaN
# Doctor                124343.75  180440.0  235069.25  407228.0
# High School or Below   52044.75   61806.0   71344.00   93875.0
# Master                 88120.00  105487.0  118530.00  133080.0

# %% [markdown]
# ##### Tras analizar las comparaciones, veo que tan solo hay información estadísticamente significativa en la relación entre salario y educación finalizada #####

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Comparar Salary por Gender
plt.figure(figsize=(10, 6))
sns.boxplot(x='Gender', y='Salary', data=df_union_clean2_pos)
plt.title('Distribución del Salary por Gender')
plt.show()

# Comparar Salary por Marital Status
plt.figure(figsize=(10, 6))
sns.boxplot(x='Marital Status', y='Salary', data=df_union_clean2_pos)
plt.title('Distribución del Salary por Marital Status')
plt.show()

# Comparar Salary por Education
plt.figure(figsize=(14, 8))
sns.boxplot(x='Education', y='Salary', data=df_union_clean2_pos)
plt.title('Distribución del Salary por Education')
plt.xticks(rotation=45)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Ajusta el tamaño de la figura
plt.figure(figsize=(10, 6))

# Crea el histograma para el salario por género
sns.histplot(data=df_union_clean2_pos, x='Salary', hue='Education', multiple='stack', bins=30)

# Añade el título del gráfico
plt.title('Distribución del Salary por Education')

# Muestra el gráfico
plt.show()

# %% [markdown]
# ##### AHORA SÍ: IMPUTACIÓN DE NULOS #####
#
# Tras analizar los datos más profundamente, veo que las personas cuyo nivel de estudio es Collegue, son aquellas que no tienen ningún salario. Esto me lleva a deducir que esas personas son estudiantes pues solo tienen terminado el colegio, probablemente todavía continúan sus estudios y es por ello que no tienen salario. Esta deducción es muy atrevida puesto que no tenemos pruebas que confirmen esta teoría, pero tampoco datos que la desmientan.
#
# Por ello realizaré la sustitución de los valores nulos por 0, que hace referencia a la no percepción de salario.

# %%
# Importo librería 
from sklearn.impute import SimpleImputer

# Crear una instancia de SimpleImputer para reemplazar los valores nulos por 0
imputer = SimpleImputer(strategy='constant', fill_value=0)

# Ajustar el imputer a los datos y transformar el DataFrame
df_union_clean2_pos_imp = df_union_clean2_pos['Salary'] = imputer.fit_transform(df_union_clean2_pos[['Salary']])
print(df_union_clean2_pos_imp)
# Out:
# [[92552.]
#  [92552.]
#  [92552.]
#  ...
#  [46594.]
#  [46594.]
#  [46594.]]

# %%
# lo siguiente que tenemos que hacer es introducir este array en nuestro DataFrame, en este caso sobreescribiremos la columna original. 
df_union_clean = df_union_clean2_pos.copy()
df_union_clean["Salary"] = df_union_clean2_pos_imp

# Comprobamos si tenemos nulos. 
print(f"Después del 'SimpleImputer' tenemos {df_union_clean['Salary'].isnull().sum()} nulos")
# Out:
# Después del 'SimpleImputer' tenemos 0 nulos

# %%
# Por último verificamos si tenemos el valor 0 en la columna salary (el valor de nulos que teníamos era de 102.672, por lo que debe ser la misma cifra)
numero_de_ceros = (df_union_clean['Salary'] == 0).sum()
print(f"Hay {numero_de_ceros} ceros en la columna 'Salary'.")
# Out:
# Hay 102672 ceros en la columna 'Salary'.

# %%
df_union_clean.describe().T
# Out:
#                        count           mean            std       min  \
# Loyalty Number      405624.0  550037.873084  258935.286969  100018.0
# Salary              405624.0   59288.321401   45743.424464       0.0
# Year                405624.0    2017.500000       0.500001    2017.0
# Month               405624.0       6.500000       3.452057       1.0
# Flights Booked      405624.0       4.115052       5.225518       0.0
# Total Flights       405624.0       5.146858       6.521227       0.0
# Distance            405624.0    1208.880059    1433.155320       0.0
# Points Accumulated  405624.0     123.692721     146.599831       0.0
#
#                           25%       50%        75%       max
# Loyalty Number      326961.00  550834.0  772194.00  999986.0
# Salary                   0.00   63669.0   82940.00  407228.0
# Year                  2017.00    2017.5    2018.00    2018.0
# Month                    3.75       6.5       9.25      12.0
# Flights Booked           0.00       1.0       8.00      21.0
# Total Flights            0.00       1.0      10.00      32.0
# Distance                 0.00     488.0    2336.00    6293.0
# Points Accumulated       0.00      50.0     239.00     676.5

# %% [markdown]
# # VISUALIZACIÓN #

# %% [markdown]
# ##### Responderemos a una serie de preguntas relacionadas con los datos de nuestro DF
#
# 1. ¿Cómo se distribuye la cantidad de vuelos reservados por mes durante el año?

# %%
# Primero importamos las librerías que necesitamos para la visualización

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Creo una gráfica básica usando 'sns.scatterplot()' que es adecuada para revisar la distribución de una variable numérica en función de otra variable 
# también numérica.
sns.scatterplot(x = "Month", 
                y = "Flights Booked",
                color='#40E0D0', 
                data = df_union_clean)

# Cambio los nombres de los ejes
plt.xlabel("Meses")
plt.ylabel("Vuelos reservados");

# Añado un título a la gráfica
plt.title("Distribución del número de vuelos reservados a lo largo del año");

# %% [markdown]
# ##### Como era de esperar, los meses con mayor número de reservas son en verano, entre junio y agosto. Sin embargo la diferencia con el resto del año no es muy grande

# %% [markdown]
# ##### 2. ¿Existe una relación entre la distancia de los vuelos y los puntos acumulados por los cliente?

# %%
# Creo una gráfica básica usando 'sns.regplot()' para evaluar la relación que existe entre dos variables numéricas y si existe una correlación lineal 
# entre ellas pues en principio considero que así será.
sns.regplot(x = "Distance", 
            y = "Points Accumulated", 
            data = df_union_clean, 
            marker = "d",
            line_kws = {"color": "pink", "linewidth": 1}, # cambio el color y el grosor de la linea de tendencia
            scatter_kws = {"color": "teal", "s": 1}) # cambio el color y el tamaño de los puntos del scaterplot          


# cambiamos los nombres de los ejes como hemos estado haciendo hasta ahora
plt.xlabel("Distancia")
plt.ylabel("Puntos acumulados")

# ponemos título a la gráfica
plt.title("Relación entre la distancia de los vuelos y los puntos acumulados");

# %% [markdown]
# ##### Confirmo viendo los datos que a mayor distancia recorrida mayor acumulación de puntos. Observo también que la linea de tendencia marca el recorrido de los datos. Sin duda hay una realación entre dichas variables.

# %% [markdown]
# 3. ¿Cuál es la distribución de los clientes por provincia o estado?

# %%
# En este caso no vamos a comparar variable, si no analizar la distribución de clientes en función de la variable 'Province', la cual e categorica. 
# Por ello usamos un gráfico de barras con el mñetido '.countplot()' 

# en este caso hemos añadido el parámetro 'order' para ordenar el nombre de las etiquetas y que aparezcan las barras de mayor cantidad a menor. 
sns.countplot(x = 'Province', 
              data = df_union_clean,
              color = '#FFCCFF')
# giramos las etiquetas del eje "x", en este caso a 90º. En este caso solo vamos a usar el parámetro 'rotation', 
# más adelante veremos mas ejemplos para usar los otros parámetros. 
plt.xticks(rotation = 90)

# cambiamos el nombre de los ejes usando los métodos 'plt.ylabel()' y 'plt.xlabel()' ya que estamos creando solo una gráfica
plt.xlabel('Provincia')
plt.ylabel('Conteo');

# %% [markdown]
# ##### Podemos observar que hay una gran diferencia entre las tres provincias con más clientes y el resto. Las provincias más comunes son Ontario, British Columbia y Quebec <3

# %% [markdown]
# 4 . ¿Cómo se compara el salario promedio entre los diferentes niveles educativos de los clientes?
#
# Para hacer este cáluclo, si los datos fueran homogéneos, utilizaría una gráfica 'Barplot' pero, debido a que la columna 'Salary' tiene outliers (algunos salarios son muy altos por lo que es más representativa la mediana que la media), he decidido utilizar 'Boxplot'.

# %%
# Creo el boxplot
sns.boxplot(x='Education', y='Salary', data=df_union_clean, palette='Set2')

# Calculo la media y la añado al el gráfico
mean_values = df_union_clean.groupby('Education')['Salary'].mean().values
plt.scatter(range(len(mean_values)), mean_values, color='red', label='Media', marker='o')

# Personalizo el gráfico
plt.xlabel('Nivel Educativo')
plt.ylabel('Distribución de Salarios')
plt.title('Distribución de Salarios por Nivel Educativo con Media')
plt.legend()  # Añado una leyenda para la media
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Lulú\AppData\Local\Temp\ipykernel_13308\148936354.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Education', y='Salary', data=df_union_clean, palette='Set2')

# %% [markdown]
# Podemos apreciar que hay relación entre ambas variables ya que, a mayor nivel de estudios alcanzados, mayor es el salario percibido. Observamos también que, que debido a los outliers de la variable 'Salary', la media se ve afectada por ellos y no es representativa del grupo, es decir, no es adecuada para describir el valor típico del conjunto de datos.

# %% [markdown]
# ##### 5. ¿Cuál es la proporción de clientes con diferentes tipos de tarjetas de fidelidad?
#
# En este caso, la gráfica adecuada para la visualización es el 'Pieplot'.

# %%
# Antes de nada, recordemos los valores únicos de 'Loyalty Card'
print(f'Las opciones de la variable Loyalty card son: {df_loyalty["Loyalty Card"].unique()}.')
# Out:
# Las opciones de la variable Loyalty card son: ['Star' 'Aurora' 'Nova'].

# %%
# empezamos preparando los datos para poder hacer el pieplot usando un groupby. En este caso tendremos que contar el número de clientes que tenemos por nivel educativo
df_loyalty_group = df_union_clean.groupby('Loyalty Card')['Loyalty Number'].count().reset_index()
df_loyalty_group
# Out:
#   Loyalty Card  Loyalty Number
# 0       Aurora           83832
# 1         Nova          137568
# 2         Star          184224

# %%
# lo primero que vamos a hacer es definir una lista para definir los colores que queremos para cada una de las categorías. 
# Esta lista debe tener tantos elementos como categorías tenemos en la columna de estudio (en este caso 7)
colores = ["pink", "violet", "turquoise"]


# Creo el gráfico 
plt.pie("Loyalty Number", labels= "Loyalty Card",
        data = df_loyalty_group, 
        autopct=  '%1.1f%%', 
        colors = colores, 
        textprops={'fontsize': 8}, 
        startangle=90);

# %% [markdown]
# Como podemos observar, el tipo de tarjeta más común entre les clientes es 'Star', seguido de 'Nova' y en último lugar, con menos de la mitad de clientes que 'Star', encontramos la tarjeta 'Aurora'.

# %% [markdown]
# ##### ¿Cómo se distribuyen los clientes según su estado civil y género?

# %%
# Antes de nada, recordemos los valores únicos de 'Marital Status' y 'Gender'
print(f'Las opciones de la variable Marital Status card son: {df_loyalty["Marital Status"].unique()}.')
print(f'Las opciones de la variable Gender card son: {df_loyalty["Gender"].unique()}.')
# Out:
# Las opciones de la variable Marital Status card son: ['Married' 'Divorced' 'Single'].
# Las opciones de la variable Gender card son: ['Female' 'Male'].

# %%
#
sns.countplot(x = 'Marital Status',
              hue = 'Gender',
              data = df_union_clean,
              palette = 'pastel',
              order = ['Single', 'Married', 'Divorced'])

# Cambio el nombre de los ejes 
plt.xlabel("Estado civil")
plt.ylabel("Género binario");

# %% [markdown]
# Como podemos observar, no hay diferencias estadísticamente significativas en el estado civil en función del género.
